# %%
def say_hello(student):
    #say hello to the given student name."
    print(f"Hello, {student}!")
    print("goodbye...")


def greet(students, greeting="hello"):
#     print("{greeting}, {student}!")
    print("{}, {}!".format(greeting, students))


def greet_all(greeting="hello", *students):
    print(greeting, students)
    for student in students:
        print(f"{greeting}, {student}!!")


def print_simple_linear(x, a=.5, b=0):
    linear = a*x + b
    print(linear)


def return_simple_linear(x, a=.5, b=0):
    return a*x + b

# %%
students = ["mirza", "sony", "rio", "iqbal"]

# %%
for student in students:
    say_hello(student)
# Out:
# Hello, mirza!
# goodbye...
# Hello, sony!
# goodbye...
# Hello, rio!
# goodbye...
# Hello, iqbal!
# goodbye...

# %%
greet("Hi")
# Out:
# hello, Hi!

# %%
greet(greeting="hi", students='hacktiv8')
# Out:
# hi, hacktiv8!

# %%
greet(students="hacktiv8", greeting="hi")
greet("hacktiv8", "hi")
# Out:
# hi, hacktiv8!
# hi, hacktiv8!

# %%
greet("hacktiv8")
greet("hacktiv8", "halo")
# Out:
# hello, hacktiv8!
# halo, hacktiv8!

# %%
greet_all("hacktiv8", "jakarta", "indonesia", "world")
# Out:
# hacktiv8 ('jakarta', 'indonesia', 'world')
# hacktiv8, jakarta!!
# hacktiv8, indonesia!!
# hacktiv8, world!!

# %%
greet_all(*students)
greet_all('halo', *students)
# Out:
# mirza ('sony', 'rio', 'iqbal')
# mirza, sony!!
# mirza, rio!!
# mirza, iqbal!!
# halo ('mirza', 'sony', 'rio', 'iqbal')
# halo, mirza!!
# halo, sony!!
# halo, rio!!
# halo, iqbal!!

# %%
a, *b = [1, 2, 3, 4]
print(a, b)
# Out:
# 1 [2, 3, 4]

# %%
compute = lambda a, b, x: a*x + b
compute(b=10, a=2, x=100)
# Out:
# 210

# %%
greets = greet_all("hacktiv8", "jakarta", "indonesia", "world")
# Out:
# hacktiv8 ('jakarta', 'indonesia', 'world')
# hacktiv8, jakarta!!
# hacktiv8, indonesia!!
# hacktiv8, world!!

# %%
result = print_simple_linear(10)
print(result)
# Out:
# 5.0
# None

# %%
result = print_simple_linear(x=100)
result2 = result**2
# Out:
# 50.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-66ee8e30af6b> in <module>
#       1 result = print_simple_linear(x=100)
# ----> 2 result2 = result**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'NoneType' and 'int'

# %%
result = return_simple_linear(10)
print(result)
# Out:
# 5.0

# %%
def compute_all(x, a=0.5, b=0):
    linear = a*x + b
    linear2 = linear + result
    return linear2

# %%
result = 100

print(result)
result2 = compute(50, 0.5, 0)
print(result, result2)

result = compute_all(50)
print(result)
# Out:
# 100
# 100 0.5
# 125.0

# %%
# !pip install model
import model
# Out:
# ERROR: Could not find a version that satisfies the requirement model (from versions: none)
# ERROR: No matching distribution found for model
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-b1507e8975de> in <module>
#       1 get_ipython().system('pip install model')
# ----> 2 import model
#
# ModuleNotFoundError: No module named 'model'

# %%
dir(model)

# %%
h8_students = model.students
# rio_students = model.rio_students
print(h8_students)
# print(rio_students)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-2d5f34767cd0> in <module>
# ----> 1 h8_students = model.students
#       2 # rio_students = model.rio_students
#       3 print(h8_students)
#       4 # print(rio_students)
#
# NameError: name 'model' is not defined

# %%
import sys

# %%
model.compute(10)

# %%
import datetime, math, os

# %%
os

# %%
datetime

# %%
math

# %%
from model import compute as c, students as s
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-699837d08eeb> in <module>
# ----> 1 from model import compute as c, students as s
#
# ModuleNotFoundError: No module named 'model'

# %%
c(10)

# %%
s

# %%
egg_count = 0

def buy_eggs():
    egg_count += 12 #purchase a doze eggs
    
buy_eggs
# Out:
# <function __main__.buy_eggs()>

# %%
# !conda install model
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - model
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
conda install -c conda-forge model
# Out:
# Collecting package metadata (current_repodata.json): failed
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://conda.anaconda.org/conda-forge/osx-64/current_repodata.json>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
# 'https://conda.anaconda.org/conda-forge/osx-64'
#
#
#
# Note: you may need to restart the kernel to use updated packages.
